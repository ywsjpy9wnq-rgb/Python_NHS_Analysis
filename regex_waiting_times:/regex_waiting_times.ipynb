# %%
import re

messages = [
    "I've been waiting for 13 weeks for my appointment.",
    "I think I have waited around 19 weeks.",
    "My family have waited up to 16 weeks.",
    "Unfortunately, my appointment was delayed by 24 weeks.",
    "I was told to wait for 8 weeks before my next check-up, but I waited 10 weeks.",
    "I don't remember how long I have been waiting.",
    "I only waited for 25 days."
]

#Regex: look for a number (1-2 digits) followed by " weeks"
pattern = r'\b(\d{1,2})\s+weeks\b'

waiting_times = []
for msg in messages:
    matches = re.findall(pattern, msg)
    waiting_times.extend(matches)

print("Extracted waiting times (weeks):", waiting_times)
# Out:
# Extracted waiting times (weeks): ['13', '19', '16', '24', '8', '10']
