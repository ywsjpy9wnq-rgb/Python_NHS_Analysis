# %%
import pandas as pd

df = pd.read_csv('/Users/matthewgibbs/Documents/Work/Current/Portfolio/Coding/nhs_database/data/nhs_waiting_lists.csv')

#Sort and get top 3
top3 = df.nlargest(3, 'total_waiting_list')[['organisation_name', 'total_waiting_list']]
print(top3)
# Out:
#                              organisation_name  total_waiting_list
# 54  MANCHESTER UNIVERSITY NHS FOUNDATION TRUST            191327.0
# 57    MID AND SOUTH ESSEX NHS FOUNDATION TRUST            178550.0
# 78      ROYAL FREE LONDON NHS FOUNDATION TRUST            142323.0
